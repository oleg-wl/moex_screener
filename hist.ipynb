# %%
from main import Moex

# %%
r = Moex()
data = r.get_trade_history(secid='GAZP')

# %%
cols = data['history']['columns']
vals = data['history']['data']

# %%
vals
# Out:
# [['EQNE',
#   '2006-01-23',
#   'ГАЗПРОМ ао',
#   'GAZP',
#   4896,
#   1130994540.44,
#   239.5,
#   218.49,
#   239.5,
#   219.2,
#   220.86,
#   218.89,
#   5120765,
#   221.08,
#   None,
#   221.08,
#   None,
#   None,
#   None,
#   None,
#   3],
#  ['EQNE',
#   '2006-01-24',
#   'ГАЗПРОМ ао',
#   'GAZP',
#   4220,
#   1991942490.56,
#   221,
#   219.66,
#   224.68,
#   223.6,
#   221.74,
#   224,
#   8983192,
#   221.4,
#   None,
#   221.4,
#   None,
#   None,
#   None,
#   None,
#   3],
#  ['EQNE',
#   '2006-01-25',
#   'ГАЗПРОМ ао',
#   'GAZP',
#   6944,
#   3534136643.92,
#   225.5,
#   225,
#   231,
#   228.48,
#   228.3,
#   228.38,
#   15480374,
#   228.29,
#   None,
#   228.29,
#   None,
#   None,
#   None,
#   None,
#   3],
#  ['EQNE',
#   '2006-01-26',
#   'ГАЗПРОМ ао',
#   'GAZP',
#   5108,
#   1721375606.3,
#   228.2,
#   223.51,
#   229.41,
#   225.12,
#   226.83,
#   224.47,
#   7588759,
#   226.99,
#   None,
#   226.99,
#   None,
#   None,
#   None,
#   None,
# ...

# %%
params={'from':'2022-01-01','till':'2037-12-31',
        'start':0, 'limit':100,
        'numtrades':10}

# %%
params['start'] = 1

# %%
params
